# %% [markdown]
# <a href="https://colab.research.google.com/github/raulpacheco2k/Sigmoidal-Python-Do-Zero/blob/main/Tratando_dados_com_fun%C3%A7%C3%B5es_Lambda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Data set com informações da cidade do Airbnb em relação a cidade do Rio de Janeiro, Rio de Janeiro, Brasil](http://insideairbnb.com/get-the-data.html)

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/content/listings.csv.gz")

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20210426010946   2021-04-30
# 1  24480  https://www.airbnb.com/rooms/24480  20210426010946   2021-04-27
# 2  35636  https://www.airbnb.com/rooms/35636  20210426010946   2021-04-30
# 3  35764  https://www.airbnb.com/rooms/35764  20210426010946   2021-04-27
# 4  41198  https://www.airbnb.com/rooms/41198  20210426010946   2021-04-27
#
#                                                 name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                   Nice and cozy near Ipanema Beach
# 2                   Cosy flat close to Ipanema beach
# 3     COPACABANA SEA BREEZE  -  RIO - 20 X Superhost
# 4                  Modern 2bed,Top end of Copacabana
#
#                                          description  \
# 0  Discounts for long term stays. <br />- Large b...
# 1  My studio is located in the best  of Ipanema. ...
# ...

# %%
df["price"]
# Out:
# 0        $190.00
# 1        $311.00
# 2        $267.00
# 3        $120.00
# 4        $493.00
#           ...
# 26462    $176.00
# 26463    $260.00
# 26464    $140.00
# 26465    $350.00
# 26466     $52.00
# Name: price, Length: 26467, dtype: object

# %%
df["price"] = df["price"].apply(lambda x: float(x.replace("$", "").replace(",", "")))

# %%
df["price"]
# Out:
# 0        190.0
# 1        311.0
# 2        267.0
# 3        120.0
# 4        493.0
#          ...
# 26462    176.0
# 26463    260.0
# 26464    140.0
# 26465    350.0
# 26466     52.0
# Name: price, Length: 26467, dtype: float64

# %%
df["price"].median()
# Out:
# 260.0

# %%
df = pd.read_excel("https://www.dropbox.com/s/69pajozeme6ezjc/solicitacoes-de-reconhecimento-da-condicao-de-refugiado.xlsx?dl=1")

# %%
df.head()
# Out:
#   Tipo de Alertas e Restrições Nacionalidade  Mês/Ano  UF  Quantidade
# 0       SOLICITAÇÃO DE REFÚGIO   AFEGANISTÃO  12/2001  DF           1
# 1       SOLICITAÇÃO DE REFÚGIO   AFEGANISTÃO  01/2010  DF           1
# 2       SOLICITAÇÃO DE REFÚGIO   AFEGANISTÃO  03/2010  DF           2
# 3       SOLICITAÇÃO DE REFÚGIO   AFEGANISTÃO  03/2010  SP           2
# 4       SOLICITAÇÃO DE REFÚGIO   AFEGANISTÃO  08/2010  DF           1

# %%
df["Tipo de Alertas e Restrições"] = df["Tipo de Alertas e Restrições"].apply(lambda x: x.capitalize())

# %%
df["Nacionalidade"] = df["Nacionalidade"].apply(lambda x: x.title())

# %%
df.head()
# Out:
#   Tipo de Alertas e Restrições Nacionalidade  Mês/Ano  UF  Quantidade
# 0       Solicitação de refúgio   Afeganistão  12/2001  DF           1
# 1       Solicitação de refúgio   Afeganistão  01/2010  DF           1
# 2       Solicitação de refúgio   Afeganistão  03/2010  DF           2
# 3       Solicitação de refúgio   Afeganistão  03/2010  SP           2
# 4       Solicitação de refúgio   Afeganistão  08/2010  DF           1
