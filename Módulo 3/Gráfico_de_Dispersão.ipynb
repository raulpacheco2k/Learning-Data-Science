# %% [markdown]
# <a href="https://colab.research.google.com/github/raulpacheco2k/Sigmoidal-Python-Do-Zero/blob/main/Gr%C3%A1fico_de_Dispers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 0    -122.23     37.88  ...            452600.0         NEAR BAY
# 1    -122.22     37.86  ...            358500.0         NEAR BAY
# 2    -122.24     37.85  ...            352100.0         NEAR BAY
# 3    -122.25     37.85  ...            341300.0         NEAR BAY
# 4    -122.25     37.85  ...            342200.0         NEAR BAY
#
# [5 rows x 10 columns]

# %%
df.plot.scatter(x='total_rooms', y='total_bedrooms', s=0.1)

# %%
df.plot.scatter(x='total_rooms', y='population', s=0.1)

# %%
df.plot.scatter(x='total_bedrooms', y='population', s=0.1)

# %%
df.plot.scatter(x='median_income', y='median_house_value', s=0.1)
